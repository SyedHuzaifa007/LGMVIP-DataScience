# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedHuzaifa007/LGMVIP-DataScience/blob/main/Pencil_Sketch_With_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Author:** Syed Huzaifa
# ##### **Data Science Intern At Lets Grow More**
# ---
# ##### **Begginer Level (Task-4)**
# **Task:** Conversion of an RGB image to Grayscale image using OpenCV and Python.

# %%
# Importing Required Libraries & Modules
import cv2
from google.colab.patches import cv2_imshow

# %%
# Reading Image
image = cv2.imread("/content/drive/MyDrive/Lets Grow More Internship/Beginner Level (Task-4)/Landscape.jpg")

# %%
# Resizing Image
dim = (800,500)
res_image = cv2.resize(image, dim)

# %%
# Displaying Image
cv2_imshow(res_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500 at 0x7F9F05122CD0>
# -1

# %%
# Converting Original Image To Grayscale Image
gray_image = cv2.cvtColor(res_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F0515C510>

# %%
# Inverting The Grayscale Image
inv_image = 255 - gray_image
cv2_imshow(inv_image)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F05105A50>

# %%
# Blurring The Image Using Gaussian Function
blur_image = cv2.GaussianBlur(inv_image, (21, 21), 0)
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F008520D0>

# %%
# Inverting The Blurred Image
inv_blur = 255 - blur_image
cv2_imshow(inv_blur)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F05122F10>

# %%
# Creating The Pencil Sketch of The Image
sketch = cv2.divide(gray_image, inv_blur, scale = 256)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F0086E090>

# %%
# Comparing Original Image & Pencil Sketch
cv2_imshow(res_image)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500 at 0x7F9F0084D550>
# <PIL.Image.Image image mode=L size=800x500 at 0x7F9F007AFC50>
